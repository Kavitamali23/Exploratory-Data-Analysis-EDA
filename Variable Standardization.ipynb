# %%
## I. Perform Variable Standardization operation on the dataset ‘auto-mpg.csv’.

# %%
# load dataset
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# 2. Using df create a new dataframe df1 with features 'displacement' and 'weight'

# %%
df1=df[['displacement','weight']]
df1
# Out:
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]

# %%
#. Import Standard Scaler from sklearn library and perform the Standardization on df1 features.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc
# Out:
# StandardScaler()

# %%
df1=sc.fit_transform(df1)
df1
# Out:
# array([[ 1.0906037 ,  0.63086987],
#        [ 1.5035143 ,  0.85433297],
#        [ 1.19623199,  0.55047045],
#        [ 1.06179598,  0.54692342],
#        [ 1.04259084,  0.56584093],
#        [ 2.26211751,  1.62049216],
#        [ 2.50218182,  1.63586264],
#        [ 2.36774581,  1.58620417],
#        [ 2.51178439,  1.71980909],
#        [ 1.88761719,  1.03996105],
#        [ 1.82039919,  0.7006282 ],
#        [ 1.40748858,  0.75501604],
#        [ 1.98364292,  0.93473239],
#        [ 2.51178439,  0.1366499 ],
#        [-0.77229532, -0.70754402],
#        [ 0.04392332, -0.16248324],
#        [ 0.0535259 , -0.23224156],
#        [ 0.06312847, -0.45333997],
#        [-0.92593647, -0.99367137],
#        [-0.92593647, -1.34246298],
#        [-0.80110303, -0.35284069],
#        [-0.82991075, -0.63896804],
#        [-0.85871847, -0.70399699],
#        [-0.69547474, -0.87070755],
#        [ 0.0535259 , -0.38121696],
#        [ 1.59954003,  1.94445453],
#        [ 1.0906037 ,  1.66187422],
# ...

# %%
#4. Create dataframe df1 with standardized data with feature names 'Displacement, Weight'

# %%
df1=pd.DataFrame(data=df1,columns=['Displacement','Weight'])
df1
# Out:
#      Displacement    Weight
# 0        1.090604  0.630870
# 1        1.503514  0.854333
# 2        1.196232  0.550470
# 3        1.061796  0.546923
# 4        1.042591  0.565841
# ..            ...       ...
# 393     -0.513026 -0.213324
# 394     -0.925936 -0.993671
# 395     -0.561039 -0.798585
# 396     -0.705077 -0.408411
# 397     -0.714680 -0.296088
#
# [398 rows x 2 columns]

# %%
#5. Concatenate df and df1 in df.

# %%
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Displacement    Weight
# 0            70       1  chevrolet chevelle malibu      1.090604  0.630870
# ...

# %%
#6. Drop the features 'displacement, weight' from df.
df.drop(['displacement', 'weight'],axis=1,inplace=True)

# %%
df
# Out:
#       mpg  cylinders horsepower  acceleration  model year  origin  \
# 0    18.0          8        130          12.0          70       1
# 1    15.0          8        165          11.5          70       1
# 2    18.0          8        150          11.0          70       1
# 3    16.0          8        150          12.0          70       1
# 4    17.0          8        140          10.5          70       1
# ..    ...        ...        ...           ...         ...     ...
# 393  27.0          4         86          15.6          82       1
# 394  44.0          4         52          24.6          82       2
# 395  32.0          4         84          11.6          82       1
# 396  28.0          4         79          18.6          82       1
# 397  31.0          4         82          19.4          82       1
#
#                       car name  Displacement    Weight
# 0    chevrolet chevelle malibu      1.090604  0.630870
# 1            buick skylark 320      1.503514  0.854333
# ...

# %% [markdown]
# # II. Perform Variable Normalization operation using Min-Max Scaler on the dataset 'auto-mpg.csv.'

# %%
#1. Load dataset ‘auto-mpg.csv'. Create a dataframe df

# %%
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#2. Using df create a new dataframe df1 with features 'displacement' and 'weight'

# %%
df1=df[['displacement','weight']]
df1
# Out:
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]

# %%
#3. Import Min-Max Scaler from sklearn library and perform the Normalization on the features of df1.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms=MinMaxScaler()

# %%
ms
# Out:
# MinMaxScaler()

# %%
df1=ms.fit_transform(df1)
df1
# Out:
# array([[0.61757106, 0.5361497 ],
#        [0.72868217, 0.58973632],
#        [0.64599483, 0.51686986],
#        [0.60981912, 0.51601928],
#        [0.60465116, 0.52055571],
#        [0.93281654, 0.77346187],
#        [0.99741602, 0.77714772],
#        [0.96124031, 0.76523958],
#        [1.        , 0.79727814],
#        [0.83204134, 0.63425007],
#        [0.81395349, 0.5528778 ],
#        [0.70284238, 0.56592005],
#        [0.85788114, 0.60901616],
#        [1.        , 0.41763538],
#        [0.11627907, 0.21519705],
#        [0.33591731, 0.34590303],
#        [0.33850129, 0.32917494],
#        [0.34108527, 0.27615537],
#        [0.0749354 , 0.1465835 ],
#        [0.0749354 , 0.06294301],
#        [0.10852713, 0.30025517],
#        [0.10077519, 0.23164162],
#        [0.09302326, 0.21604763],
#        [0.1369509 , 0.17607031],
#        [0.33850129, 0.29345052],
#        [0.75452196, 0.85114828],
#        [0.61757106, 0.78338531],
#        [0.64599483, 0.78508648],
# ...

# %%
#4. Create dataframe df1 with normalized data with feature names 'Displacement, Weight'.

# %%
df1=pd.DataFrame(data=df1,columns=['Displacement','Weight'])
df1
# Out:
#      Displacement    Weight
# 0        0.617571  0.536150
# 1        0.728682  0.589736
# 2        0.645995  0.516870
# 3        0.609819  0.516019
# 4        0.604651  0.520556
# ..            ...       ...
# 393      0.186047  0.333711
# 394      0.074935  0.146583
# 395      0.173127  0.193365
# 396      0.134367  0.286929
# 397      0.131783  0.313864
#
# [398 rows x 2 columns]

# %%
# concatination of df and df1
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  Displacement    Weight
# 0            70       1  chevrolet chevelle malibu      0.617571  0.536150
# ...

# %%
#6. Drop the features 'displacement, weight' from df.

# %%
df.drop(['displacement', 'weight'],axis=1,inplace=True)

# %%
df
# Out:
#       mpg  cylinders horsepower  acceleration  model year  origin  \
# 0    18.0          8        130          12.0          70       1
# 1    15.0          8        165          11.5          70       1
# 2    18.0          8        150          11.0          70       1
# 3    16.0          8        150          12.0          70       1
# 4    17.0          8        140          10.5          70       1
# ..    ...        ...        ...           ...         ...     ...
# 393  27.0          4         86          15.6          82       1
# 394  44.0          4         52          24.6          82       2
# 395  32.0          4         84          11.6          82       1
# 396  28.0          4         79          18.6          82       1
# 397  31.0          4         82          19.4          82       1
#
#                       car name  Displacement    Weight
# 0    chevrolet chevelle malibu      0.617571  0.536150
# 1            buick skylark 320      0.728682  0.589736
# ...

# %% [markdown]
# # III. Perform Feature Scaling operation using Maxabs Scaler on the dataset ‘auto-mpg.csv.

# %%
# 1. load dataset
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#2. Using df create a new dataframe df1 with features only having float data type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df1=df[['mpg','displacement','acceleration']]
df1
# Out:
#       mpg  displacement  acceleration
# 0    18.0         307.0          12.0
# 1    15.0         350.0          11.5
# 2    18.0         318.0          11.0
# 3    16.0         304.0          12.0
# 4    17.0         302.0          10.5
# ..    ...           ...           ...
# 393  27.0         140.0          15.6
# 394  44.0          97.0          24.6
# 395  32.0         135.0          11.6
# 396  28.0         120.0          18.6
# 397  31.0         119.0          19.4
#
# [398 rows x 3 columns]

# %%
# 3. Import Maxabs Scaler from sklearn library and perform the feature scaling on the features of df1.

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
ma=MaxAbsScaler()

# %%
ma
# Out:
# MaxAbsScaler()

# %%
df1=ma.fit_transform(df1)
df1
# Out:
# array([[0.38626609, 0.67472527, 0.48387097],
#        [0.32188841, 0.76923077, 0.46370968],
#        [0.38626609, 0.6989011 , 0.44354839],
#        ...,
#        [0.68669528, 0.2967033 , 0.46774194],
#        [0.60085837, 0.26373626, 0.75      ],
#        [0.66523605, 0.26153846, 0.78225806]])

# %%
#4. Create dataframe df1 with the scaled data.

# %%
df1=pd.DataFrame(data=df1,columns=['MPG','Displacement','Acceleration'])
df1
# Out:
#           MPG  Displacement  Acceleration
# 0    0.386266      0.674725      0.483871
# 1    0.321888      0.769231      0.463710
# 2    0.386266      0.698901      0.443548
# 3    0.343348      0.668132      0.483871
# 4    0.364807      0.663736      0.423387
# ..        ...           ...           ...
# 393  0.579399      0.307692      0.629032
# 394  0.944206      0.213187      0.991935
# 395  0.686695      0.296703      0.467742
# 396  0.600858      0.263736      0.750000
# 397  0.665236      0.261538      0.782258
#
# [398 rows x 3 columns]

# %%
# concate df and df1
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name       MPG  Displacement  \
# ...

# %%
# Drop feature from df
df.drop(['mpg','displacement','acceleration'],axis=1,inplace=True)

# %%
df
# Out:
#      cylinders horsepower  weight  model year  origin  \
# 0            8        130    3504          70       1
# 1            8        165    3693          70       1
# 2            8        150    3436          70       1
# 3            8        150    3433          70       1
# 4            8        140    3449          70       1
# ..         ...        ...     ...         ...     ...
# 393          4         86    2790          82       1
# 394          4         52    2130          82       2
# 395          4         84    2295          82       1
# 396          4         79    2625          82       1
# 397          4         82    2720          82       1
#
#                       car name       MPG  Displacement  Acceleration
# 0    chevrolet chevelle malibu  0.386266      0.674725      0.483871
# 1            buick skylark 320  0.321888      0.769231      0.463710
# 2           plymouth satellite  0.386266      0.698901      0.443548
# ...

# %% [markdown]
# # IV. Perform Feature Scaling operation using Robust Scaler on the dataset ‘auto-mpg.csv.
# 1. Load dataset ‘auto-mpg.csv'. Create a dataframe df.
# 2. Using df create a new dataframe df1 with features only having float data type.
# 3. Import Robust Scaler from sklearn library and perform the feature scaling on the features of df1.
# 4. Create dataframe df1 with the scaled data.
# 5. Concatenate df and df1 in df.
# 6. Drop the features original features which are scaled from the df.

# %%
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df1=df[['mpg','displacement','acceleration']]
df1
# Out:
#       mpg  displacement  acceleration
# 0    18.0         307.0          12.0
# 1    15.0         350.0          11.5
# 2    18.0         318.0          11.0
# 3    16.0         304.0          12.0
# 4    17.0         302.0          10.5
# ..    ...           ...           ...
# 393  27.0         140.0          15.6
# 394  44.0          97.0          24.6
# 395  32.0         135.0          11.6
# 396  28.0         120.0          18.6
# 397  31.0         119.0          19.4
#
# [398 rows x 3 columns]

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs=RobustScaler()

# %%
rs
# Out:
# RobustScaler()

# %%
df1=rs.fit_transform(df1)
df1
# Out:
# array([[-0.43478261,  1.00475436, -1.04477612],
#        [-0.69565217,  1.27733756, -1.19402985],
#        [-0.43478261,  1.07448494, -1.34328358],
#        ...,
#        [ 0.7826087 , -0.08557845, -1.1641791 ],
#        [ 0.43478261, -0.18066561,  0.92537313],
#        [ 0.69565217, -0.18700475,  1.1641791 ]])

# %%
df1=pd.DataFrame(data=df1,columns=['MPG','Displacement','Acceleration'])
df1
# Out:
#           MPG  Displacement  Acceleration
# 0   -0.434783      1.004754     -1.044776
# 1   -0.695652      1.277338     -1.194030
# 2   -0.434783      1.074485     -1.343284
# 3   -0.608696      0.985737     -1.044776
# 4   -0.521739      0.973059     -1.492537
# ..        ...           ...           ...
# 393  0.347826     -0.053883      0.029851
# 394  1.826087     -0.326466      2.716418
# 395  0.782609     -0.085578     -1.164179
# 396  0.434783     -0.180666      0.925373
# 397  0.695652     -0.187005      1.164179
#
# [398 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name       MPG  Displacement  \
# ...

# %%
df.drop(['mpg','displacement','acceleration'],axis=1,inplace=True)

# %%
df
# Out:
#      cylinders horsepower  weight  model year  origin  \
# 0            8        130    3504          70       1
# 1            8        165    3693          70       1
# 2            8        150    3436          70       1
# 3            8        150    3433          70       1
# 4            8        140    3449          70       1
# ..         ...        ...     ...         ...     ...
# 393          4         86    2790          82       1
# 394          4         52    2130          82       2
# 395          4         84    2295          82       1
# 396          4         79    2625          82       1
# 397          4         82    2720          82       1
#
#                       car name       MPG  Displacement  Acceleration
# 0    chevrolet chevelle malibu -0.434783      1.004754     -1.044776
# 1            buick skylark 320 -0.695652      1.277338     -1.194030
# 2           plymouth satellite -0.434783      1.074485     -1.343284
# ...

# %% [markdown]
# # V. Perform Feature Scaling operation using Quantile Transformer Scaler on the dataset ‘auto-mpg.csv.
# 1. Load dataset ‘auto-mpg.csv'. Create a dataframe df.
# 2. Using df create a new dataframe df1 with features only having float data type.
# 3. Import Quantile Transformer Scaler from sklearn library and perform feature scaling on the features of df1.
# 4. Create dataframe df1 with the scaled data.
# 5. Concatenate df and df1 in df.
# 6. Drop the features original features which are scaled from the df.

# %%
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df1=df[['mpg','displacement','acceleration']]
df1
# Out:
#       mpg  displacement  acceleration
# 0    18.0         307.0          12.0
# 1    15.0         350.0          11.5
# 2    18.0         318.0          11.0
# 3    16.0         304.0          12.0
# 4    17.0         302.0          10.5
# ..    ...           ...           ...
# 393  27.0         140.0          15.6
# 394  44.0          97.0          24.6
# 395  32.0         135.0          11.6
# 396  28.0         120.0          18.6
# 397  31.0         119.0          19.4
#
# [398 rows x 3 columns]

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
qt=QuantileTransformer()

# %%
qt
# Out:
# QuantileTransformer()

# %%
df1=qt.fit_transform(df1)
df1
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2667: UserWarning: n_quantiles (1000) is greater than the total number of samples (398). n_quantiles is set to n_samples.
#   warnings.warn(
# array([[0.28967254, 0.81234257, 0.08942065],
#        [0.15365239, 0.88539043, 0.06549118],
#        [0.28967254, 0.83879093, 0.03526448],
#        ...,
#        [0.83627204, 0.43576826, 0.07556675],
#        [0.71662469, 0.35768262, 0.8627204 ],
#        [0.80604534, 0.33879093, 0.91687657]])

# %%
df1=pd.DataFrame(data=df1,columns=['MPG','Displacement','Acceleration'])
df1
# Out:
#           MPG  Displacement  Acceleration
# 0    0.289673      0.812343      0.089421
# 1    0.153652      0.885390      0.065491
# 2    0.289673      0.838791      0.035264
# 3    0.202771      0.789673      0.089421
# 4    0.239295      0.768262      0.025189
# ..        ...           ...           ...
# 393  0.677582      0.462217      0.539043
# 394  0.992443      0.168766      0.997481
# 395  0.836272      0.435768      0.075567
# 396  0.716625      0.357683      0.862720
# 397  0.806045      0.338791      0.916877
#
# [398 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name       MPG  Displacement  \
# ...

# %%
df.drop(['mpg','displacement','acceleration'],axis=1,inplace=True)

# %%
df
# Out:
#      cylinders horsepower  weight  model year  origin  \
# 0            8        130    3504          70       1
# 1            8        165    3693          70       1
# 2            8        150    3436          70       1
# 3            8        150    3433          70       1
# 4            8        140    3449          70       1
# ..         ...        ...     ...         ...     ...
# 393          4         86    2790          82       1
# 394          4         52    2130          82       2
# 395          4         84    2295          82       1
# 396          4         79    2625          82       1
# 397          4         82    2720          82       1
#
#                       car name       MPG  Displacement  Acceleration
# 0    chevrolet chevelle malibu  0.289673      0.812343      0.089421
# 1            buick skylark 320  0.153652      0.885390      0.065491
# 2           plymouth satellite  0.289673      0.838791      0.035264
# ...

# %% [markdown]
# VI. Perform Feature Scaling operation using Power Transformer Scaler on the dataset ‘auto-mpg.csv.
# 1. Load dataset ‘auto-mpg.csv'. Create a dataframe df.
# 2. Using df create a new dataframe df1 with features only having float data type.
# 3. Import Power Transformer Scaler from sklearn library and perform feature scaling on the features of df1.
# 4. Create dataframe df1 with the scaled data.
# 5. Concatenate df and df1 in df.
# 6. Drop the features original features which are scaled from the df.#

# %%
df=pd.read_excel('auto-mpg.xlsx')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df1=df[['mpg','displacement','acceleration']]
df1
# Out:
#       mpg  displacement  acceleration
# 0    18.0         307.0          12.0
# 1    15.0         350.0          11.5
# 2    18.0         318.0          11.0
# 3    16.0         304.0          12.0
# 4    17.0         302.0          10.5
# ..    ...           ...           ...
# 393  27.0         140.0          15.6
# 394  44.0          97.0          24.6
# 395  32.0         135.0          11.6
# 396  28.0         120.0          18.6
# 397  31.0         119.0          19.4
#
# [398 rows x 3 columns]

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
pt
# Out:
# PowerTransformer()

# %%
df1=pt.fit_transform(df1)
df1
# Out:
# array([[-0.64551283,  1.12979327, -1.32727149],
#        [-1.15216632,  1.33284087, -1.53186393],
#        [-0.64551283,  1.18513402, -1.74027006],
#        ...,
#        [ 1.08349177, -0.34765624, -1.49064744],
#        [ 0.66449588, -0.59152854,  1.09508489],
#        [ 0.98289115, -0.60918853,  1.3610129 ]])

# %%
df1=pd.DataFrame(data=df1,columns=['MPG','Displacement','Acceleration'])
df1
# Out:
#           MPG  Displacement  Acceleration
# 0   -0.645513      1.129793     -1.327271
# 1   -1.152166      1.332841     -1.531864
# 2   -0.645513      1.185134     -1.740270
# 3   -0.975080      1.114248     -1.327271
# 4   -0.806477      1.103773     -1.952725
# ..        ...           ...           ...
# 393  0.552249     -0.274101      0.050072
# 394  2.126698     -1.054715      2.983826
# 395  1.083492     -0.347656     -1.490647
# 396  0.664496     -0.591529      1.095085
# 397  0.982891     -0.609189      1.361013
#
# [398 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name       MPG  Displacement  \
# ...

# %%
df.drop(['mpg','displacement','acceleration'],axis=1,inplace=True)
df
# Out:
#      cylinders horsepower  weight  model year  origin  \
# 0            8        130    3504          70       1
# 1            8        165    3693          70       1
# 2            8        150    3436          70       1
# 3            8        150    3433          70       1
# 4            8        140    3449          70       1
# ..         ...        ...     ...         ...     ...
# 393          4         86    2790          82       1
# 394          4         52    2130          82       2
# 395          4         84    2295          82       1
# 396          4         79    2625          82       1
# 397          4         82    2720          82       1
#
#                       car name       MPG  Displacement  Acceleration
# 0    chevrolet chevelle malibu -0.645513      1.129793     -1.327271
# 1            buick skylark 320 -1.152166      1.332841     -1.531864
# 2           plymouth satellite -0.645513      1.185134     -1.740270
# ...

# %% [markdown]
# # part B

# %% [markdown]
# # Perform Feature Scaling on the dataset ‘Titanic-Dataset.csv’.
# 1. Load dataset ‘Titanic-Dataset.csv.
# 2. Perform Standardization on the variables: - Age, Fare (Use Standard Scaler)
# 3. Perform feature scaling using – Min-max Scaler on the features: - Pclass, Age, SibSp, Parch, Fare.
# 4. Perform feature scaling using –Robust Scaler on the features: - Pclass, Age, SibSp, Parch, Fare.
# 5. Perform feature scaling using –Power Transform Scaler on the features: - Pclass, Age, SibSp, Parch, Fare.
# 6. Perform feature scaling using –Quantile Transform Scaler on the features: - Pclass, Age, SibSp, Parch, Fare.

# %%
df=pd.read_excel('Titanic-Dataset.xlsx')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean().round())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1=df.copy()
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df1[['Age','Fare']]
df2
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888  30.0  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc
# Out:
# StandardScaler()

# %%
df2=sc.fit_transform(df2)
df2
# Out:
# array([[-0.59705478, -0.50244517],
#        [ 0.63416229,  0.78684529],
#        [-0.28925051, -0.48885426],
#        ...,
#        [ 0.01855376, -0.17626324],
#        [-0.28925051, -0.04438104],
#        [ 0.17245589, -0.49237783]])

# %%
df2=pd.DataFrame(data=df2,columns=['AGE','FARE'])
df2
# Out:
#           AGE      FARE
# 0   -0.597055 -0.502445
# 1    0.634162  0.786845
# 2   -0.289251 -0.488854
# 3    0.403309  0.420730
# 4    0.403309 -0.486337
# ..        ...       ...
# 886 -0.212299 -0.386671
# 887 -0.827908 -0.044381
# 888  0.018554 -0.176263
# 889 -0.289251 -0.044381
# 890  0.172456 -0.492378
#
# [891 rows x 2 columns]

# %%
df1=pd.concat([df1,df2],axis=1)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.drop(['Age','Fare'],axis=1,inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df3=df.copy()
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4=df3[['Pclass','Age','SibSp','Parch','Fare']]
df4
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3  30.0      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms=MinMaxScaler()

# %%
ms
# Out:
# MinMaxScaler()

# %%
df4=ms.fit_transform(df4)
df4
# Out:
# array([[1.        , 0.27117366, 0.125     , 0.        , 0.01415106],
#        [0.        , 0.4722292 , 0.125     , 0.        , 0.13913574],
#        [1.        , 0.32143755, 0.        , 0.        , 0.01546857],
#        ...,
#        [1.        , 0.37170143, 0.125     , 0.33333333, 0.04577135],
#        [0.        , 0.32143755, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.39683338, 0.        , 0.        , 0.01512699]])

# %%
df4=pd.DataFrame(data=df4,columns=['PCLASS','AGE','SIBSP', 'PARCH', 'FARE'])
df4
# Out:
#      PCLASS       AGE  SIBSP     PARCH      FARE
# 0       1.0  0.271174  0.125  0.000000  0.014151
# 1       0.0  0.472229  0.125  0.000000  0.139136
# 2       1.0  0.321438  0.000  0.000000  0.015469
# 3       0.0  0.434531  0.125  0.000000  0.103644
# 4       1.0  0.434531  0.000  0.000000  0.015713
# ..      ...       ...    ...       ...       ...
# 886     0.5  0.334004  0.000  0.000000  0.025374
# 887     0.0  0.233476  0.000  0.000000  0.058556
# 888     1.0  0.371701  0.125  0.333333  0.045771
# 889     0.0  0.321438  0.000  0.000000  0.058556
# 890     1.0  0.396833  0.000  0.000000  0.015127
#
# [891 rows x 5 columns]

# %%
df3=pd.concat([df3,df4],axis=1)
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)

# %%
df3
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df5=df.copy()
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df6=df5[['Pclass','Age','SibSp','Parch','Fare']]
df6
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3  30.0      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs=RobustScaler()

# %%
rs
# Out:
# RobustScaler()

# %%
df6=rs.fit_transform(df6)
df6
# Out:
# array([[ 0.        , -0.61538462,  1.        ,  0.        , -0.3120106 ],
#        [-2.        ,  0.61538462,  1.        ,  0.        ,  2.46124229],
#        [ 0.        , -0.30769231,  0.        ,  0.        , -0.28277666],
#        ...,
#        [ 0.        ,  0.        ,  1.        ,  2.        ,  0.38960398],
#        [-2.        , -0.30769231,  0.        ,  0.        ,  0.67328148],
#        [ 0.        ,  0.15384615,  0.        ,  0.        , -0.29035583]])

# %%
df6=pd.DataFrame(data=df6,columns=['PCLASS','AGE','SIBSP', 'PARCH', 'FARE'])
df6
# Out:
#      PCLASS       AGE  SIBSP  PARCH      FARE
# 0       0.0 -0.615385    1.0    0.0 -0.312011
# 1      -2.0  0.615385    1.0    0.0  2.461242
# 2       0.0 -0.307692    0.0    0.0 -0.282777
# 3      -2.0  0.384615    1.0    0.0  1.673732
# 4       0.0  0.384615    0.0    0.0 -0.277363
# ..      ...       ...    ...    ...       ...
# 886    -1.0 -0.230769    0.0    0.0 -0.062981
# 887    -2.0 -0.846154    0.0    0.0  0.673281
# 888     0.0  0.000000    1.0    2.0  0.389604
# 889    -2.0 -0.307692    0.0    0.0  0.673281
# 890     0.0  0.153846    0.0    0.0 -0.290356
#
# [891 rows x 5 columns]

# %%
df5=pd.concat([df5,df6],axis=1)
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df5.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)

# %%
df5
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df7=df.copy()
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df8=df7[['Pclass','Age','SibSp','Parch','Fare']]
df8
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3  30.0      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
pt
# Out:
# PowerTransformer()

# %%
df8=pt.fit_transform(df8)
df8
# Out:
# array([[ 0.86397329, -0.5618802 ,  1.37363642, -0.56025296, -0.87882001],
#        [-1.45912855,  0.65217572,  1.37363642, -0.56025296,  1.33665056],
#        [ 0.86397329, -0.24738629, -0.67984996, -0.56025296, -0.79006485],
#        ...,
#        [ 0.86397329,  0.05902543,  1.37363642,  1.84685634,  0.28888536],
#        [-1.45912855, -0.24738629, -0.67984996, -0.56025296,  0.52790578],
#        [ 0.86397329,  0.20959457, -0.67984996, -0.56025296, -0.81234947]])

# %%
df8=pd.DataFrame(data=df8,columns=['PCLASS','AGE','SIBSP', 'PARCH', 'FARE'])
df8
# Out:
#        PCLASS       AGE     SIBSP     PARCH      FARE
# 0    0.863973 -0.561880  1.373636 -0.560253 -0.878820
# 1   -1.459129  0.652176  1.373636 -0.560253  1.336651
# 2    0.863973 -0.247386 -0.679850 -0.560253 -0.790065
# 3   -1.459129  0.432501  1.373636 -0.560253  1.067352
# 4    0.863973  0.432501 -0.679850 -0.560253 -0.774439
# ..        ...       ...       ...       ...       ...
# 886 -0.592604 -0.170080 -0.679850 -0.560253 -0.294907
# 887 -1.459129 -0.804048 -0.679850 -0.560253  0.527906
# 888  0.863973  0.059025  1.373636  1.846856  0.288885
# 889 -1.459129 -0.247386 -0.679850 -0.560253  0.527906
# 890  0.863973  0.209595 -0.679850 -0.560253 -0.812349
#
# [891 rows x 5 columns]

# %%
df7=pd.concat([df7,df8],axis=1)
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df7.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)

# %%
df7
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df9=df.copy()
df9
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df10=df9[['Pclass','Age','SibSp','Parch','Fare']]
df10
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3  30.0      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
from sklearn.preprocessing import QuantileTransformer

# %%
qt=QuantileTransformer()

# %%
qt
# Out:
# QuantileTransformer()

# %%
df10=qt.fit_transform(df10)
df10
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:2667: UserWarning: n_quantiles (1000) is greater than the total number of samples (891). n_quantiles is set to n_samples.
#   warnings.warn(
# array([[1.        , 0.24325843, 0.8005618 , 0.        , 0.08483146],
#        [0.        , 0.79494382, 0.8005618 , 0.        , 0.88539326],
#        [1.        , 0.34775281, 0.        , 0.        , 0.25955056],
#        ...,
#        [1.        , 0.54438202, 0.8005618 , 0.93820225, 0.61235955],
#        [0.        , 0.34775281, 0.        , 0.        , 0.73370787],
#        [1.        , 0.68932584, 0.        , 0.        , 0.13764045]])

# %%
df10=pd.DataFrame(data=df10,columns=['PCLASS','AGE','SIBSP', 'PARCH', 'FARE'])
df10
# Out:
#        PCLASS       AGE     SIBSP     PARCH      FARE
# 0    1.000000  0.243258  0.800562  0.000000  0.084831
# 1    0.000000  0.794944  0.800562  0.000000  0.885393
# 2    1.000000  0.347753  0.000000  0.000000  0.259551
# 3    0.000000  0.746067  0.800562  0.000000  0.838764
# 4    1.000000  0.746067  0.000000  0.000000  0.295506
# ..        ...       ...       ...       ...       ...
# 886  0.344944  0.367978  0.000000  0.000000  0.456180
# 887  0.000000  0.169101  0.000000  0.000000  0.733708
# 888  1.000000  0.544382  0.800562  0.938202  0.612360
# 889  0.000000  0.347753  0.000000  0.000000  0.733708
# 890  1.000000  0.689326  0.000000  0.000000  0.137640
#
# [891 rows x 5 columns]

# %%
df9=pd.concat([df9,df10],axis=1)
df9
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
