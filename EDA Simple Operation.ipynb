# %% [markdown]
# # EDA assignment 1:Basic Attribute and method
# ## Kavita Jyotiba Mali
# ## 2223010025
# # #Dummy data Opertaion

# %%
import pandas as pd

# %%
Data={'Name':['Kavita','Neha','Sushant','Sayali','Swara','Santosh','Sakshi','Karan','Sanket','Yash','Yogita','Mantesh'],
     'Age':[21,20,22,19,19,23,20,21,22,23,25,26],
     'Gender':['Female','Female','Male','Female','Female','Male','Female','Male','Male','Male','Female','Male'],
     'Salary':[20000,22000,21000,18000,19000,20000,22000,25000,32000,40000,20000,18500]}

# %%
# 1.create a Dataframe
df=pd.DataFrame(Data)

# %%
df
# Out:
#        Name  Age  Gender  Salary
# 0    Kavita   21  Female   20000
# 1      Neha   20  Female   22000
# 2   Sushant   22    Male   21000
# 3    Sayali   19  Female   18000
# 4     Swara   19  Female   19000
# 5   Santosh   23    Male   20000
# 6    Sakshi   20  Female   22000
# 7     Karan   21    Male   25000
# 8    Sanket   22    Male   32000
# 9      Yash   23    Male   40000
# 10   Yogita   25  Female   20000
# 11  Mantesh   26    Male   18500

# %%
# 2.Find shape of data
df.shape
# Out:
# (12, 4)

# %%
# 3. Find  size of dataframe
df.size
# Out:
# 48

# %%
# 4. find dimention of data
df.ndim
# Out:
# 2

# %%
# 5. List all the columns in the df
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
# 6. Find datatype of each column in the data
df.dtypes
# Out:
# Name      object
# Age        int64
# Gender    object
# Salary     int64
# dtype: object

# %%
# 7. Find axes of the df.
df.axes
# Out:
# [RangeIndex(start=0, stop=12, step=1),
#  Index(['Name', 'Age', 'Gender', 'Salary'], dtype='object')]

# %%
# 8. Find index of the df.
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
#9. Find all values of df
df.values
# Out:
# array([['Kavita', 21, 'Female', 20000],
#        ['Neha', 20, 'Female', 22000],
#        ['Sushant', 22, 'Male', 21000],
#        ['Sayali', 19, 'Female', 18000],
#        ['Swara', 19, 'Female', 19000],
#        ['Santosh', 23, 'Male', 20000],
#        ['Sakshi', 20, 'Female', 22000],
#        ['Karan', 21, 'Male', 25000],
#        ['Sanket', 22, 'Male', 32000],
#        ['Yash', 23, 'Male', 40000],
#        ['Yogita', 25, 'Female', 20000],
#        ['Mantesh', 26, 'Male', 18500]], dtype=object)

# %%
#10. Check whether the df is empty.
df.empty
# Out:
# False

# %%
# 11. Transpose the df
df.T
# Out:
#             0       1        2       3       4        5       6      7
# Name    Kavita    Neha  Sushant  Sayali   Swara  Santosh  Sakshi  Karan  \
# Age         21      20       22      19      19       23      20     21
# Gender  Female  Female     Male  Female  Female     Male  Female   Male
# Salary   20000   22000    21000   18000   19000    20000   22000  25000
#
#             8      9       10       11
# Name    Sanket   Yash  Yogita  Mantesh
# Age         22     23      25       26
# Gender    Male   Male  Female     Male
# Salary   32000  40000   20000    18500

# %%
# 12. Find detailed information about the df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   Age     12 non-null     int64
#  2   Gender  12 non-null     object
#  3   Salary  12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes

# %%
# 13. Display (first) top ‘n’ records from the df.
df.head()
# Out:
#       Name  Age  Gender  Salary
# 0   Kavita   21  Female   20000
# 1     Neha   20  Female   22000
# 2  Sushant   22    Male   21000
# 3   Sayali   19  Female   18000
# 4    Swara   19  Female   19000

# %%
 # 14. Display (last) bottom ‘n’ records from the df
df.tail()
# Out:
#        Name  Age  Gender  Salary
# 7     Karan   21    Male   25000
# 8    Sanket   22    Male   32000
# 9      Yash   23    Male   40000
# 10   Yogita   25  Female   20000
# 11  Mantesh   26    Male   18500

# %%
# 15. Display descriptive statistics for numerical columns from the df.
df.describe()
# Out:
#             Age        Salary
# count  12.00000     12.000000
# mean   21.75000  23125.000000
# std     2.22077   6523.123206
# min    19.00000  18000.000000
# 25%    20.00000  19750.000000
# 50%    21.50000  20500.000000
# 75%    23.00000  22750.000000
# max    26.00000  40000.000000

# %%
# 16. Find mean, median, mode, standard deviation values for numerical columns in df.
df.describe()
# Out:
#             Age        Salary
# count  12.00000     12.000000
# mean   21.75000  23125.000000
# std     2.22077   6523.123206
# min    19.00000  18000.000000
# 25%    20.00000  19750.000000
# 50%    21.50000  20500.000000
# 75%    23.00000  22750.000000
# max    26.00000  40000.000000

# %%
# 17. Return a random sample from df.
random_sample=df.sample()
random_sample
# Out:
#      Name  Age  Gender  Salary
# 0  Kavita   21  Female   20000

# %%
# 18. Find the unique values for the categorical columns in the df.
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# 19. Find the number of unique values for categorical columns in df.
df['Gender'].nunique()
# Out:
# 2

# %%
# 20. Locate first row in the df using loc.
df.loc[0]
# Out:
# Name      Kavita
# Age           21
# Gender    Female
# Salary     20000
# Name: 0, dtype: object

# %%
# 21. Locate nth row in the df using loc.
df.loc[5]
# Out:
# Name      Santosh
# Age            23
# Gender       Male
# Salary      20000
# Name: 5, dtype: object

# %%
#22. Locate last row in the df using loc.
df.loc[11]
# Out:
# Name      Mantesh
# Age            26
# Gender       Male
# Salary      18500
# Name: 11, dtype: object

# %%
# 23. Locate all values in a range in df using loc.
df.loc[0:3]
# Out:
#       Name  Age  Gender  Salary
# 0   Kavita   21  Female   20000
# 1     Neha   20  Female   22000
# 2  Sushant   22    Male   21000
# 3   Sayali   19  Female   18000

# %%
# 24. Locate all the rows in df with specific criteria using loc.
df.loc[df['Age']>20]
# Out:
#        Name  Age  Gender  Salary
# 0    Kavita   21  Female   20000
# 2   Sushant   22    Male   21000
# 5   Santosh   23    Male   20000
# 7     Karan   21    Male   25000
# 8    Sanket   22    Male   32000
# 9      Yash   23    Male   40000
# 10   Yogita   25  Female   20000
# 11  Mantesh   26    Male   18500

# %%
# 25. Locate all the rows in df with specific criteria with logical and operator using loc.
df.loc[(df['Age']>20) & (df['Age']<=25)]
# Out:
#        Name  Age  Gender  Salary
# 0    Kavita   21  Female   20000
# 2   Sushant   22    Male   21000
# 5   Santosh   23    Male   20000
# 7     Karan   21    Male   25000
# 8    Sanket   22    Male   32000
# 9      Yash   23    Male   40000
# 10   Yogita   25  Female   20000

# %%
# 26. Locate first row in the df using iloc.
df.iloc[0]
# Out:
# Name      Kavita
# Age           21
# Gender    Female
# Salary     20000
# Name: 0, dtype: object

# %%
# 27. Locate nth row in the df using iloc.
df.iloc[5]
# Out:
# Name      Santosh
# Age            23
# Gender       Male
# Salary      20000
# Name: 5, dtype: object

# %%
# 28. Locate last row in the df using iloc.
df.iloc[-1]
# Out:
# Name      Mantesh
# Age            26
# Gender       Male
# Salary      18500
# Name: 11, dtype: object

# %%
# 29. Locate first, nth, last column in df using iloc.
df.iloc[:,[0,2,-1]]
# Out:
#        Name  Gender  Salary
# 0    Kavita  Female   20000
# 1      Neha  Female   22000
# 2   Sushant    Male   21000
# 3    Sayali  Female   18000
# 4     Swara  Female   19000
# 5   Santosh    Male   20000
# 6    Sakshi  Female   22000
# 7     Karan    Male   25000
# 8    Sanket    Male   32000
# 9      Yash    Male   40000
# 10   Yogita  Female   20000
# 11  Mantesh    Male   18500

# %%
# 30. Locate all the rows in df within a specific range of row index using iloc.
df.iloc[0:3]
# Out:
#       Name  Age  Gender  Salary
# 0   Kavita   21  Female   20000
# 1     Neha   20  Female   22000
# 2  Sushant   22    Male   21000

# %%
# 31. Locate all columns within a range of column index using iloc.
df.iloc[:, 0:3]
# Out:
#        Name  Age  Gender
# 0    Kavita   21  Female
# 1      Neha   20  Female
# 2   Sushant   22    Male
# 3    Sayali   19  Female
# 4     Swara   19  Female
# 5   Santosh   23    Male
# 6    Sakshi   20  Female
# 7     Karan   21    Male
# 8    Sanket   22    Male
# 9      Yash   23    Male
# 10   Yogita   25  Female
# 11  Mantesh   26    Male

# %%
# 32. Locate Second through third rows and first 2 columns using iloc.
df.iloc[1:3,0:2]
# Out:
#       Name  Age
# 1     Neha   20
# 2  Sushant   22

# %%
# 33. Locate 1st and 6th rows and 1st and 4th columns using iloc.
df.iloc[[0,5],[0,3]]
# Out:
#       Name  Salary
# 0   Kavita   20000
# 5  Santosh   20000

# %%
# 34. Save the created data in a csv, excel file and reload and check.
df.to_csv("data1.csv")
df.to_excel('data1.xlsx')

# %%
pd.read_csv('data1.csv')
# Out:
#     Unnamed: 0     Name  Age  Gender  Salary
# 0            0   Kavita   21  Female   20000
# 1            1     Neha   20  Female   22000
# 2            2  Sushant   22    Male   21000
# 3            3   Sayali   19  Female   18000
# 4            4    Swara   19  Female   19000
# 5            5  Santosh   23    Male   20000
# 6            6   Sakshi   20  Female   22000
# 7            7    Karan   21    Male   25000
# 8            8   Sanket   22    Male   32000
# 9            9     Yash   23    Male   40000
# 10          10   Yogita   25  Female   20000
# 11          11  Mantesh   26    Male   18500

# %%
df2=pd.read_excel('data1.xlsx')
df2
# Out:
#     Unnamed: 0     Name  Age  Gender  Salary
# 0            0   Kavita   21  Female   20000
# 1            1     Neha   20  Female   22000
# 2            2  Sushant   22    Male   21000
# 3            3   Sayali   19  Female   18000
# 4            4    Swara   19  Female   19000
# 5            5  Santosh   23    Male   20000
# 6            6   Sakshi   20  Female   22000
# 7            7    Karan   21    Male   25000
# 8            8   Sanket   22    Male   32000
# 9            9     Yash   23    Male   40000
# 10          10   Yogita   25  Female   20000
# 11          11  Mantesh   26    Male   18500

# %% [markdown]
# # Using Titanic dataset performing operation

# %%
df1=pd.read_excel('Titanic-Dataset.xlsx')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#2. Find shape of the df
df1.shape
# Out:
# (891, 12)

# %%
# 3. Find size of the df.
df1.size
# Out:
# 10692

# %%
# 4. Find dimensions of the df
df1.ndim
# Out:
# 2

# %%
# 5. List all the columns in the df
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 6. Find datatype of each column in the df.
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# 7. Find axes of the df.
df1.axes
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
# 8. Find index of the df.
df1.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#9. Find all values of df
df1.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
# 10. Check whether the df is empty.
df1.empty
# Out:
# False

# %%
# 11. Transpose the df
df1.T
# Out:
#                                  0
# PassengerId                        1  \
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1
# PassengerId                                                  2  \
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
#                                 2
# PassengerId                       3  \
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
# Age                            26.0
# SibSp                             0
# Parch                             0
# Ticket             STON/O2. 3101282
# Fare                          7.925
# Cabin                           NaN
# Embarked                          S
#
#                                                       3
# PassengerId                                             4  \
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                  35.0
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
#                                   4                 5
# PassengerId                         5                 6  \
# Survived                            0                 0
# Pclass                              3                 3
# Name         Allen, Mr. William Henry  Moran, Mr. James
# Sex                              male              male
# Age                              35.0               NaN
# SibSp                               0                 0
# Parch                               0                 0
# Ticket                         373450            330877
# Fare                             8.05            8.4583
# Cabin                             NaN               NaN
# Embarked                            S                 Q
#
#                                  6                               7
# PassengerId                        7                               8  \
# Survived                           0                               0
# Pclass                             1                               3
# Name         McCarthy, Mr. Timothy J  Palsson, Master. Gosta Leonard
# Sex                             male                            male
# Age                             54.0                             2.0
# SibSp                              0                               3
# Parch                              0                               1
# Ticket                         17463                          349909
# Fare                         51.8625                          21.075
# Cabin                            E46                             NaN
# Embarked                           S                               S
#
#                                                            8
# PassengerId                                                  9  \
# Survived                                                     1
# Pclass                                                       3
# Name         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Sex                                                     female
# Age                                                       27.0
# SibSp                                                        0
# Parch                                                        2
# Ticket                                                  347742
# Fare                                                   11.1333
# Cabin                                                      NaN
# Embarked                                                     S
#
#                                              9    ...                 881
# PassengerId                                   10  ...                 882  \
# Survived                                       1  ...                   0
# Pclass                                         2  ...                   3
# Name         Nasser, Mrs. Nicholas (Adele Achem)  ...  Markun, Mr. Johann
# Sex                                       female  ...                male
# Age                                         14.0  ...                33.0
# SibSp                                          1  ...                   0
# Parch                                          0  ...                   0
# Ticket                                    237736  ...              349257
# Fare                                     30.0708  ...              7.8958
# Cabin                                        NaN  ...                 NaN
# Embarked                                       C  ...                   S
#
#                                       882                            883
# PassengerId                           883                            884  \
# Survived                                0                              0
# Pclass                                  3                              2
# Name         Dahlberg, Miss. Gerda Ulrika  Banfield, Mr. Frederick James
# Sex                                female                           male
# Age                                  22.0                           28.0
# SibSp                                   0                              0
# Parch                                   0                              0
# Ticket                               7552               C.A./SOTON 34068
# Fare                              10.5167                           10.5
# Cabin                                 NaN                            NaN
# Embarked                                S                              S
#
#                                 884                                   885
# PassengerId                     885                                   886  \
# Survived                          0                                     0
# Pclass                            3                                     3
# Name         Sutehall, Mr. Henry Jr  Rice, Mrs. William (Margaret Norton)
# Sex                            male                                female
# Age                            25.0                                  39.0
# SibSp                             0                                     0
# Parch                             0                                     5
# Ticket              SOTON/OQ 392076                                382652
# Fare                           7.05                                29.125
# Cabin                           NaN                                   NaN
# Embarked                          S                                     Q
#
#                                886                           887
# PassengerId                    887                           888  \
# Survived                         0                             1
# Pclass                           2                             1
# Name         Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# Sex                           male                        female
# Age                           27.0                          19.0
# SibSp                            0                             0
# Parch                            0                             0
# Ticket                      211536                        112053
# Fare                          13.0                          30.0
# Cabin                          NaN                           B42
# Embarked                         S                             S
#
#                                                   888                    889
# PassengerId                                       889                    890  \
# Survived                                            0                      1
# Pclass                                              3                      1
# Name         Johnston, Miss. Catherine Helen "Carrie"  Behr, Mr. Karl Howell
# Sex                                            female                   male
# Age                                               NaN                   26.0
# SibSp                                               1                      0
# Parch                                               2                      0
# Ticket                                     W./C. 6607                 111369
# Fare                                            23.45                   30.0
# Cabin                                             NaN                   C148
# Embarked                                            S                      C
#
#                              890
# PassengerId                  891
# Survived                       0
# Pclass                         3
# Name         Dooley, Mr. Patrick
# Sex                         male
# Age                         32.0
# SibSp                          0
# Parch                          0
# Ticket                    370376
# Fare                        7.75
# Cabin                        NaN
# Embarked                       Q
#
# [12 rows x 891 columns]

# %%
# 12. Find detailed information about the df.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 13. Display (first) top ‘n’ records from the df.
df1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 14. Display (first) bottom ‘n’ records from the df.
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 886          887         0       2                     Montvila, Rev. Juozas  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 15. Display descriptive statistics for numerical columns from the 
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 16. Find mean, median, mode, standard deviation values for numerical columns in 
df1.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5  \
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# 17. Return a random sample from df.
df1.sample()
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  Age
# 480          481         0       3  Goodwin, Master. Harold Victor  male  9.0  \
#
#      SibSp  Parch   Ticket  Fare Cabin Embarked
# 480      5      2  CA 2144  46.9   NaN        S

# %%
#18. Find the unique values for the categorical columns in the 
df1['Sex'].unique
# Out:
# <bound method Series.unique of 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object>

# %%
# 19. Find the number of unique values for categorical columns in 
df1['Sex'].nunique()
# Out:
# 2

# %%
# 20. Locate first row in the df using loc.
df1.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# 21. Locate nth row in the df using loc.
df.loc[5]
# Out:
# Name      Santosh
# Age            23
# Gender       Male
# Salary      20000
# Name: 5, dtype: object

# %%
# 22. Locate last row in the df using loc.
last_row_index=df1.index[-1]
df1.loc[last_row_index]
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %%
# 23. Locate all values in a range in df using loc.
df1.loc[0:20]
# Out:
#     PassengerId  Survived  Pclass
# 0             1         0       3  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C
# 20      0            239865  26.0000   NaN        S

# %%
# 24. Locate all the rows in df with specific criteria using loc.
df1.loc[df1['Age']>25]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# 6        0             17463  51.8625   E46        S
# ..     ...               ...      ...   ...      ...
# 883      0  C.A./SOTON 34068  10.5000   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [413 rows x 12 columns]

# %%
# 25. Locate all the rows in df with specific criteria with logical and operator using loc.
df1.loc[(df1['Age']>20)*(df1['Age']<25)]
# Out:
#      PassengerId  Survived  Pclass                                   Name
# 0              1         0       3                Braund, Mr. Owen Harris  \
# 37            38         0       3               Cann, Mr. Ernest Charles
# 51            52         0       3           Nosworthy, Mr. Richard Cater
# 56            57         1       2                      Rugg, Miss. Emily
# 60            61         0       3                  Sirayanian, Mr. Orsen
# ..           ...       ...     ...                                    ...
# 836          837         0       3                       Pasic, Mr. Jakob
# 858          859         1       3  Baclini, Mrs. Solomon (Latifa Qurban)
# 861          862         0       2            Giles, Mr. Frederick Edward
# 864          865         0       2                 Gill, Mr. John William
# 882          883         0       3           Dahlberg, Miss. Gerda Ulrika
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0   A/5 21171   7.2500   NaN        S
# 37     male  21.0      0      0  A./5. 2152   8.0500   NaN        S
# 51     male  21.0      0      0  A/4. 39886   7.8000   NaN        S
# 56   female  21.0      0      0  C.A. 31026  10.5000   NaN        S
# 60     male  22.0      0      0        2669   7.2292   NaN        C
# ..      ...   ...    ...    ...         ...      ...   ...      ...
# 836    male  21.0      0      0      315097   8.6625   NaN        S
# 858  female  24.0      0      3        2666  19.2583   NaN        C
# 861    male  21.0      1      0       28134  11.5000   NaN        S
# 864    male  24.0      0      0      233866  13.0000   NaN        S
# 882  female  22.0      0      0        7552  10.5167   NaN        S
#
# [99 rows x 12 columns]

# %%
# 26. Locate first row in the df using iloc.
df1.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# 27. Locate nth row in the df using iloc.
df1.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
# 28. Locate last row in the df using iloc.
df1.iloc[-1]
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %%
# 29. Locate first, nth, last column in df using iloc.
df1.iloc[:,[0,5,-1]]
# Out:
#      PassengerId   Age Embarked
# 0              1  22.0        S
# 1              2  38.0        C
# 2              3  26.0        S
# 3              4  35.0        S
# 4              5  35.0        S
# ..           ...   ...      ...
# 886          887  27.0        S
# 887          888  19.0        S
# 888          889   NaN        S
# 889          890  26.0        C
# 890          891  32.0        Q
#
# [891 rows x 3 columns]

# %%
# 30. Locate all the rows in df within a specific range of row index using iloc.
df1.iloc[3:8]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                            Name     Sex   Age  SibSp  Parch
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0  \
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                Palsson, Master. Gosta Leonard    male   2.0      3      1
#
#    Ticket     Fare Cabin Embarked
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
# 7  349909  21.0750   NaN        S

# %%
# 31. Locate all columns within a range of column index using iloc.
df1.iloc[:,3:6]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
#32. Locate Second through third rows and first 2 columns using iloc.
df1.iloc[1:3,0:2]
# Out:
#    PassengerId  Survived
# 1            2         1
# 2            3         1

# %%
# 33. Locate 1st and 6th rows and 1st and 4th columns using iloc.
df1.iloc[[0,6],[1,5]]
# Out:
#    Survived   Age
# 0         0  22.0
# 6         0  54.0

# %%
# 34. Save the created data in a csv, excel file and reload and check.
df1.to_csv("Titanic.csv")

# %%
df1.to_excel('Titanic2.xlsx')

# %%
pd.read_csv("Titanic.csv")
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass
# 0             0            1         0       3  \
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]
