# %% [markdown]
# # Assignment No 3
# ## Name: Kavita Jyotiba Mali
# ## PRN No:2223010025

# %%
## A. Perform the following Operations
import pandas as pd

# %% [markdown]
# # WDICountry.csv

# %%
df=pd.read_excel("WDICountry.xlsx")

# %%
df
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 265          AUS                    Australia                    Australia
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...

# %%
df.shape
# Out:
# (267, 29)

# %%
df.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data'],
#       dtype='object')

# %%
#1.1 Identify missing (Null, NaN) values in the entire dataset and print the count of the same feature wise.
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           2
# Currency Unit                                         48
# Region                                                48
# Income Group                                          50
# WB-2 code                                              1
# National accounts base year                           56
# National accounts reference year                     192
# SNA price valuation                                   58
# Lending category                                     122
# Other groups                                         208
# System of National Accounts                           57
# Alternative conversion factor                        267
# ...

# %%
#1.2 Identify the total count of null values in the entire dataset.

# %%
df.isnull().sum().sum()
# Out:
# 2606

# %%
#1.3 Perform appropriate imputations to handle the missing values.

# %%
df.head(50)
# Out:
#    Country Code                      Short Name
# 0           ABW                           Aruba  \
# 1           AFE     Africa Eastern and Southern
# 2           AFG                     Afghanistan
# 3           AFW      Africa Western and Central
# 4           AGO                          Angola
# 5           ALB                         Albania
# 6           AND                         Andorra
# 7           ARB                      Arab World
# 8           ARE            United Arab Emirates
# 9           ARG                       Argentina
# 10          ARM                         Armenia
# 11          ASM                  American Samoa
# 12          ATG             Antigua and Barbuda
# 13          AUS                       Australia
# 14          AUT                         Austria
# 15          AZE                      Azerbaijan
# 16          BDI                         Burundi
# 17          BEL                         Belgium
# ...

# %%
df['2-alpha code'].unique()
# Out:
# array(['AW', 'ZH', 'AF', 'ZI', 'AO', 'AL', 'AD', '1A', 'AE', 'AR', 'AM',
#        'AS', 'AG', 'AU', 'AT', 'AZ', 'BI', 'BE', 'BJ', 'BF', 'BD', 'BG',
#        'BH', 'BS', 'BA', 'BY', 'BZ', 'BM', 'BO', 'BR', 'BB', 'BN', 'BT',
#        'BW', 'CF', 'CA', 'B8', 'CH', nan, 'CL', 'CN', 'CI', 'CM', 'CD',
#        'CG', 'CO', 'KM', 'CV', 'CR', 'S3', 'CU', 'CW', 'KY', 'CY', 'CZ',
#        'DE', 'DJ', 'DM', 'DK', 'DO', 'DZ', '4E', 'V2', 'Z4', '7E', 'Z7',
#        'EC', 'EG', 'XC', 'ER', 'ES', 'EE', 'ET', 'EU', 'F1', 'FI', 'FJ',
#        'FR', 'FO', 'FM', 'GA', 'GB', 'GE', 'GH', 'GI', 'GN', 'GM', 'GW',
#        'GQ', 'GR', 'GD', 'GL', 'GT', 'GU', 'GY', 'XD', 'HK', 'HN', 'XE',
#        'HR', 'HT', 'HU', 'XF', 'ZT', 'XG', 'XH', 'ID', 'XI', 'IM', 'IN',
#        'IE', 'IR', 'IQ', 'IS', 'IL', 'IT', 'JM', 'JO', 'JP', 'KZ', 'KE',
#        'KG', 'KH', 'KI', 'KN', 'KR', 'KW', 'XJ', 'LA', 'LB', 'LR', 'LY',
#        'LC', 'ZJ', 'XL', 'XM', 'LI', 'LK', 'XN', 'XO', 'LS', 'V3', 'LT',
# ...

# %%
missing_rows=df[df['WB-2 code'].isnull()]
missing_rows
# Out:
#     Country Code Short Name Table Name            Long Name 2-alpha code
# 170          NAM    Namibia    Namibia  Republic of Namibia          NaN  \
#
#        Currency Unit              Region         Income Group WB-2 code
# 170  Namibian dollar  Sub-Saharan Africa  Upper middle income       NaN  \
#
#     National accounts base year  ...       System of trade
# 170                        2015  ...  General trade system  \
#
#     Government Accounting concept
# 170  Budgetary central government  \
#
#                        IMF data dissemination standard
# 170  Enhanced General Data Dissemination System (e-...  \
#
#     Latest population census              Latest household survey
# 170                     2011  Demographic and Health Survey, 2013  \
#
#      Source of most recent Income and expenditure data
# 170     Expenditure survey/budget survey (ES/BS), 2015  \
#
#      Vital registration complete Latest agricultural census
# ...

# %%
df['2-alpha code'] = df['2-alpha code'].fillna('Unknown')
df['Currency Unit'] = df['Currency Unit'].fillna(df['Currency Unit'].mode()[0])
df['Region'] = df['Region'].fillna(df['Region'].mode()[0])
df['Income Group'] = df['Income Group'].fillna(df['Income Group'].mode()[0])
df['WB-2 code']=df['WB-2 code'].fillna('Unknown')

# %%
df.head(10)
# Out:
#   Country Code                   Short Name                   Table Name
# 0          ABW                        Aruba                        Aruba  \
# 1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2          AFG                  Afghanistan                  Afghanistan
# 3          AFW   Africa Western and Central   Africa Western and Central
# 4          AGO                       Angola                       Angola
# 5          ALB                      Albania                      Albania
# 6          AND                      Andorra                      Andorra
# 7          ARB                   Arab World                   Arab World
# 8          ARE         United Arab Emirates         United Arab Emirates
# 9          ARG                    Argentina                    Argentina
#
#                       Long Name 2-alpha code   Currency Unit
# 0                         Aruba           AW   Aruban florin  \
# ...

# %%
df['SNA price valuation'].unique()
# Out:
# array(['Value added at basic prices (VAB)', nan,
#        'Value added at producer prices (VAP)'], dtype=object)

# %%
df.iloc[:,0:10]
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 265          AUS                    Australia                    Australia
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                           56
# National accounts reference year                     192
# SNA price valuation                                   58
# Lending category                                     122
# Other groups                                         208
# System of National Accounts                           57
# Alternative conversion factor                        267
# ...

# %%
df['SNA price valuation'] = df['SNA price valuation'].fillna('Unknown')
df['Lending category'] = df['Lending category'].fillna('Unknown')
df['Other groups'] = df['Other groups'].fillna('Unknown')
df['System of National Accounts'] = df['System of National Accounts'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                           56
# National accounts reference year                     192
# SNA price valuation                                    0
# Lending category                                       0
# Other groups                                           0
# System of National Accounts                            0
# Alternative conversion factor                        267
# ...

# %%
df.drop(columns=['Alternative conversion factor','PPP survey year'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                           56
# National accounts reference year                     192
# SNA price valuation                                    0
# Lending category                                       0
# Other groups                                           0
# System of National Accounts                            0
# Balance of Payments Manual in use                     70
# ...

# %%
#df['Balance of Payments Manual in use'] = df['Balance of Payments Manual in use'].fillna('Unknown')
df['External debt Reporting status'] = df['External debt Reporting status'].fillna('Unknown')
df['System of trade'] = df['System of trade'].fillna(df['System of trade'].mode()[0])
df['Government Accounting concept'] = df['Government Accounting concept'].fillna(df['Government Accounting concept'].mode()[0])
df['IMF data dissemination standard'] = df['IMF data dissemination standard'].fillna(df['IMF data dissemination standard'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                           56
# National accounts reference year                     192
# SNA price valuation                                    0
# Lending category                                       0
# Other groups                                           0
# System of National Accounts                            0
# Balance of Payments Manual in use                     70
# ...

# %%
df['National accounts base year']=df['National accounts base year'].fillna(method='ffill')
df['National accounts reference year']=df['National accounts reference year'].fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                            0
# National accounts reference year                       1
# SNA price valuation                                    0
# Lending category                                       0
# Other groups                                           0
# System of National Accounts                            0
# Balance of Payments Manual in use                     70
# ...

# %%
df['Latest population census'] = df['Latest population census'].fillna(df['Latest population census'].mode()[0])
df['Latest household survey'] = df['Latest household survey'].fillna('Unknown')
df['Source of most recent Income and expenditure data'] = df['Source of most recent Income and expenditure data'].fillna('Unknown')
df['Vital registration complete'] = df['Vital registration complete'].fillna('Unknown')
df['Latest agricultural census'] = df['Latest agricultural census'].fillna(df['Latest agricultural census'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Country Code                                           0
# Short Name                                             0
# Table Name                                             0
# Long Name                                              0
# 2-alpha code                                           0
# Currency Unit                                          0
# Region                                                 0
# Income Group                                           0
# WB-2 code                                              0
# National accounts base year                            0
# National accounts reference year                       1
# SNA price valuation                                    0
# Lending category                                       0
# Other groups                                           0
# System of National Accounts                            0
# Balance of Payments Manual in use                     70
# ...

# %%
df['Latest industrial data'] = df['Latest industrial data'].fillna(df['Latest industrial data'].median())
df['Latest trade data'] = df['Latest trade data'].fillna(df['Latest trade data'].median())

# %%
df.isnull().sum()
# Out:
# Country Code                                          0
# Short Name                                            0
# Table Name                                            0
# Long Name                                             0
# 2-alpha code                                          0
# Currency Unit                                         0
# Region                                                0
# Income Group                                          0
# WB-2 code                                             0
# National accounts base year                           0
# National accounts reference year                      1
# SNA price valuation                                   0
# Lending category                                      0
# Other groups                                          0
# System of National Accounts                           0
# Balance of Payments Manual in use                    70
# External debt Reporting status                        0
# ...

# %%
df['Balance of Payments Manual in use'] = df['Balance of Payments Manual in use'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Country Code                                         0
# Short Name                                           0
# Table Name                                           0
# Long Name                                            0
# 2-alpha code                                         0
# Currency Unit                                        0
# Region                                               0
# Income Group                                         0
# WB-2 code                                            0
# National accounts base year                          0
# National accounts reference year                     1
# SNA price valuation                                  0
# Lending category                                     0
# Other groups                                         0
# System of National Accounts                          0
# Balance of Payments Manual in use                    0
# External debt Reporting status                       0
# ...

# %%
df['National accounts reference year']=df['National accounts reference year'].fillna(method='ffill')

# %%
missing_rows=df[df['National accounts reference year'].isnull()]
missing_rows
# Out:
# Empty DataFrame
# Columns: [Country Code, Short Name, Table Name, Long Name, 2-alpha code, Currency Unit, Region, Income Group, WB-2 code, National accounts base year, National accounts reference year, SNA price valuation, Lending category, Other groups, System of National Accounts, Balance of Payments Manual in use, External debt Reporting status, System of trade, Government Accounting concept, IMF data dissemination standard, Latest population census, Latest household survey, Source of most recent Income and expenditure data, Vital registration complete, Latest agricultural census, Latest industrial data, Latest trade data]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Country Code                                         0
# Short Name                                           0
# Table Name                                           0
# Long Name                                            0
# 2-alpha code                                         0
# Currency Unit                                        0
# Region                                               0
# Income Group                                         0
# WB-2 code                                            0
# National accounts base year                          0
# National accounts reference year                     0
# SNA price valuation                                  0
# Lending category                                     0
# Other groups                                         0
# System of National Accounts                          0
# Balance of Payments Manual in use                    0
# External debt Reporting status                       0
# ...

# %%
df
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 265          AUS                    Australia                    Australia
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...

# %%
#1.4 Identify the duplicate values in the dataset.
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 262    False
# 263    False
# 264    False
# 265     True
# 266    False
# Length: 267, dtype: bool

# %%
## 1.5 Keep one first duplicate value and one last duplicate value.
df.duplicated().sum()
# Out:
# 1

# %%
df1=df.loc[df.duplicated()]
df1
# Out:
#     Country Code Short Name Table Name                  Long Name
# 265          AUS  Australia  Australia  Commonwealth of Australia  \
#
#     2-alpha code      Currency Unit               Region Income Group
# 265           AU  Australian dollar  East Asia & Pacific  High income  \
#
#     WB-2 code                        National accounts base year  ...
# 265        AU  Original chained constant price data are resca...  ...  \
#
#           System of trade    Government Accounting concept
# 265  General trade system  Consolidated central government  \
#
#                 IMF data dissemination standard Latest population census
# 265  Special Data Dissemination Standard (SDDS)                     2016  \
#
#     Latest household survey Source of most recent Income and expenditure data
# 265                 Unknown    Expenditure survey/budget survey (ES/BS), 2010  \
#
#     Vital registration complete Latest agricultural census
# ...

# %%
df2=df.drop_duplicates(keep='first')
df2
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 261          YEM                        Yemen                  Yemen, Rep.
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...

# %%
df2=df.drop_duplicates(keep='last')
df2
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 265          AUS                    Australia                    Australia
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...

# %%
#1.6 Convert the categorical features into numerical features using the map function for columns – System of tradSystem of trade,

# %%
df['System of trade'].unique()
# Out:
# array(['General trade system', 'Special trade system'], dtype=object)

# %%
df['System of trade'] = df['System of trade'].map({'General trade system': 1,'Special trade system': 2})

# %%
df['Government Accounting concept'].unique()
# Out:
# array(['Consolidated central government', 'Budgetary central government'],
#       dtype=object)

# %%
df['Government Accounting concept']=df['Government Accounting concept'].map({'Consolidated central government':1,'Budgetary central government':2})

# %%
df['Vital registration complete'].unique()
# Out:
# array(['Yes', 'Unknown',
#        'Yes. Vital registration for Guernsey and Jersey.'], dtype=object)

# %%
df['Vital registration complete'] = df['Vital registration complete'].map({'Yes': 1,'Unknown': 2,'Yes. Vital registration for Guernsey and Jersey.':3})

# %%
## 1.7 Convert the categorical features into numerical features using dummy variables for columns – Region, Income Group

# %%
df['Region'].unique()
# Out:
# array(['Latin America & Caribbean', 'Europe & Central Asia', 'South Asia',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
df_region=pd.get_dummies(df['Region'],dtype=int,prefix='Region_category')
df_region
# Out:
#      Region_category_East Asia & Pacific
# 0                                      0  \
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ..                                   ...
# 262                                    0
# 263                                    0
# 264                                    0
# 265                                    1
# 266                                    0
#
#      Region_category_Europe & Central Asia
# 0                                        0  \
# 1                                        1
# 2                                        0
# 3                                        1
# 4                                        0
# ..                                     ...
# 262                                      0
# 263                                      0
# 264                                      0
# ...

# %%
df_income=pd.get_dummies(df['Income Group'],dtype=int,prefix='Income Group')
df_income
# Out:
#      Income Group_High income  Income Group_Low income
# 0                           1                        0  \
# 1                           1                        0
# 2                           0                        1
# 3                           1                        0
# 4                           0                        0
# ..                        ...                      ...
# 262                         0                        0
# 263                         0                        0
# 264                         0                        0
# 265                         1                        0
# 266                         1                        0
#
#      Income Group_Lower middle income  Income Group_Upper middle income
# 0                                   0                                 0
# 1                                   0                                 0
# 2                                   0                                 0
# ...

# %%
#1.8 Rename the columns with the prefix of the original column for dummy columns. i.e. Region_ South Asia, Income Group_ High income etc.

# %%
df.rename(columns={'Region_South Asia': 'Region_South_Asia', 'Income Group_High income': 'Income_Group_High_income'})
# Out:
#     Country Code                   Short Name                   Table Name
# 0            ABW                        Aruba                        Aruba  \
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
# 265          AUS                    Australia                    Australia
# 266          VEN                    Venezuela                Venezuela, RB
#
#                               Long Name 2-alpha code
# ...
